# %% [markdown]
# <a href="https://colab.research.google.com/github/olaronke/COMPUTATION/blob/main/Untitled53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import spacy

# %%
import nltk
from nltk.util import ngrams

# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt

# %%
def extract_ngrams(data, num):
    n_grams = ngrams(nltk.word_tokenize(data), num)
    return [ ' '.join(grams) for grams in n_grams]

# %%
from sklearn.feature_extraction.text import CountVectorizer
# get bag of words features in sparse format
cv = CountVectorizer(min_df=0., max_df=1.)
cv_matrix = cv.fit_transform(text1)
cv_matrix
#<8x20 sparse matrix of type '<class 'numpy.int64'>'
#with 42 stored elements in Compressed Sparse Row format>
# view non-zero feature positions in the sparse matrix
print(cv_matrix)
# Out:
#   (0, 37)	2
#   (0, 5)	3
#   (0, 16)	4
#   (0, 4)	1
#   (0, 14)	2
#   (0, 26)	1
#   (0, 3)	1
#   (0, 36)	1
#   (0, 6)	1
#   (0, 40)	2
#   (0, 17)	2
#   (0, 38)	1
#   (0, 30)	1
#   (0, 33)	1
#   (0, 20)	1
#   (0, 35)	2
#   (0, 18)	3
#   (0, 32)	1
#   (0, 28)	1
#   (0, 31)	4
#   (0, 39)	1
#   (0, 12)	1
#   (0, 13)	1
#   (0, 23)	1
#   (0, 34)	1
#   (0, 29)	1
#   (0, 21)	1
#   (0, 15)	1
#   (0, 27)	1
#   (0, 2)	3
#   (0, 9)	1
#   (0, 10)	1
#   (0, 25)	1
#   (0, 0)	1
#   (0, 7)	1
#   (0, 1)	1
#   (0, 22)	1
#   (0, 8)	1
#   (0, 11)	1
#   (0, 19)	1
#   (0, 41)	1
#   (0, 24)	1

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text1 = ["When a boy is born, his parents are visited by a wise man who tells them not to name their son. The wise man will give the boy a name when he is older. This is the story of how the boy seeks and eventually finds his own name and is able to discard an old dream for a new and wonderful one."]
text2 = ["When a boy visits another village, he is amazed to find the townspeople terrified of something that—just because they have not seen it before—they mistake for a terrible, dangerous animal. With his own knowledge and by demonstration, he helps them overcome their fears.Rose Mary Santiago’s illustrations accentuate the surprise in this story in a clever way that will delight youngsters. This is the second book in this series illustrated by her, following the award-winning best seller The Farmer’s Wife."]
text3 = ["A man tricks a young fox into believing that he will give it a chicken. However, the fox gets trapped but, through its ingenuity and perseverance, manages to escape. This story can inspire children to face challenges and to overcome and, sometimes, make use of obstacles in their path. Sally Mallam’s illustrations provide delightful and imaginative depictions of the characters."]

# %%
data = [text1, text2, text3]

# %%
# you can set the n-gram range to 1,2 to get unigrams as well as bigrams
bv = CountVectorizer(ngram_range=(2,2))
bv_matrix = bv.fit_transform(text1)
bv_matrix = bv_matrix.toarray()
vocab = bv.get_feature_names()
pd.DataFrame(bv_matrix, columns=vocab)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#    able to  an old  and eventually  and is  and wonderful  are visited  \
# 0        1       1               1       1              1            1
#
#    born his  boy is  boy name  boy seeks  ...  this is  to discard  to name  \
# 0         1       1         1          1  ...        1           1        1
#
#    visited by  when boy  when he  who tells  will give  wise man  \
# 0           1         1        1          1          1         2
#
#    wonderful one
# 0              1
#
# [1 rows x 56 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
# get bag of words features in sparse format
cv = CountVectorizer(min_df=0., max_df=1.)
cv_matrix = cv.fit_transform(text2)
cv_matrix
#<8x20 sparse matrix of type '<class 'numpy.int64'>'
#with 42 stored elements in Compressed Sparse Row format>
# view non-zero feature positions in the sparse matrix
print(cv_matrix)
# Out:
#   (0, 61)	1
#   (0, 10)	1
#   (0, 59)	1
#   (0, 4)	1
#   (0, 58)	1
#   (0, 22)	2
#   (0, 29)	2
#   (0, 1)	1
#   (0, 56)	1
#   (0, 18)	1
#   (0, 51)	5
#   (0, 57)	1
#   (0, 49)	1
#   (0, 36)	1
#   (0, 45)	1
#   (0, 50)	2
#   (0, 31)	1
#   (0, 6)	1
#   (0, 54)	2
#   (0, 21)	1
#   (0, 35)	1
#   (0, 42)	1
#   (0, 30)	1
#   (0, 7)	1
#   (0, 34)	1
#   :	:
#   (0, 33)	1
#   (0, 40)	1
#   (0, 27)	1
#   (0, 0)	1
#   (0, 47)	1
#   (0, 28)	3
#   (0, 55)	3
#   (0, 46)	1
#   (0, 12)	1
#   (0, 60)	1
#   (0, 63)	1
#   (0, 14)	1
#   (0, 66)	1
#   (0, 41)	1
#   (0, 9)	1
#   (0, 44)	1
#   (0, 26)	1
#   (0, 24)	1
#   (0, 19)	1
#   (0, 5)	1
#   (0, 64)	1
#   (0, 8)	1
#   (0, 43)	1
#   (0, 16)	1
#   (0, 62)	1

# %%
# you can set the n-gram range to 1,2 to get unigrams as well as bigrams
bv = CountVectorizer(ngram_range=(2,2))
bv_matrix = bv.fit_transform(text2)
bv_matrix = bv_matrix.toarray()
vocab = bv.get_feature_names()
pd.DataFrame(bv_matrix, columns=vocab)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#    accentuate the  amazed to  and by  animal with  another village  \
# 0               1          1       1            1                1
#
#    award winning  because they  before they  best seller  book in  ...  \
# 0              1             1            1            1        1  ...
#
#    to find  townspeople terrified  village he  visits another  way that  \
# 0        1                      1           1               1         1
#
#    when boy  will delight  winning best  with his  youngsters this
# 0         1             1             1         1                1
#
# [1 rows x 78 columns]

# %%
# you can set the n-gram range to 1,2 to get unigrams as well as bigrams
bv = CountVectorizer(ngram_range=(2,2))
bv_matrix = bv.fit_transform(text3)
bv_matrix = bv_matrix.toarray()
vocab = bv.get_feature_names()
pd.DataFrame(bv_matrix, columns=vocab)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#    and imaginative  and perseverance  and sometimes  and to  believing that  \
# 0                1                 1              1       1               1
#
#    but through  can inspire  challenges and  chicken however  children to  \
# 0            1            1               1                1            1
#
#    ...  this story  through its  to escape  to face  to overcome  trapped but  \
# 0  ...           1            1          1        1            1            1
#
#    tricks young  use of  will give  young fox
# 0             1       1          1          1
#
# [1 rows x 56 columns]

# %%
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
def get_cosine_sim(*strs): 
    vectors = [t for t in get_vectors(*strs)]
    return cosine_similarity(vectors)
    
def get_vectors(*strs):
    text = [t for t in strs]
    vectorizer = CountVectorizer(text)
    vectorizer.fit(text)
    return vectorizer.transform(text).toarray()

# %%
# Install; note that the prefix "!" is not needed if you are running in a terminal
# !pip install stanza

# Import the package
import stanza
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 691 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 240 kB 51.4 MB/s
# ...
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234926 sha256=2513ff4be77b40e10fe8a4d44b7c99bb331603429828fe8cc92ccab802a19b6e
#   Stored in directory: /root/.cache/pip/wheels/86/62/9e/a6b27a681abcde69970dbc0326ff51955f3beac72f15696984
# Successfully built emoji
# ...

# %%
import stanza

nlp = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma')
doc = nlp('When a boy is born, his parents are visited by a wise man who tells them not to name their son. The wise man will give the boy a name when he is older. This is the story of how the boy seeks and eventually finds his own name and is able to discard an old dream for a new and wonderful one.')
print(*[f'word: {word.text+" "}\tlemma: {word.lemma}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# ...
# INFO:stanza:Loading these models for language: en (English):
# ...
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# ...
#
# INFO:stanza:Use device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# word: When 	lemma: when
# word: a 	lemma: a
# word: boy 	lemma: boy
# word: is 	lemma: be
# word: born 	lemma: bear
# word: , 	lemma: ,
# word: his 	lemma: he
# word: parents 	lemma: parent
# word: are 	lemma: be
# word: visited 	lemma: visit
# word: by 	lemma: by
# word: a 	lemma: a
# word: wise 	lemma: wise
# word: man 	lemma: man
# ...

# %%
import stanza

nlp = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos')
doc = nlp('When a boy is born, his parents are visited by a wise man who tells them not to name their son. The wise man will give the boy a name when he is older. This is the story of how the boy seeks and eventually finds his own name and is able to discard an old dream for a new and wonderful one.')
print(*[f'word: {word.text}\tupos: {word.upos}\txpos: {word.xpos}\tfeats: {word.feats if word.feats else "_"}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# ...
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# ...
#
# INFO:stanza:Use device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# word: When	upos: SCONJ	xpos: WRB	feats: PronType=Int
# word: a	upos: DET	xpos: DT	feats: Definite=Ind|PronType=Art
# word: boy	upos: NOUN	xpos: NN	feats: Number=Sing
# word: is	upos: AUX	xpos: VBZ	feats: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# word: born	upos: VERB	xpos: VBN	feats: Tense=Past|VerbForm=Part|Voice=Pass
# word: ,	upos: PUNCT	xpos: ,	feats: _
# ...
